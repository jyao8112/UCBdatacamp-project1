# %%
import pandas as pd
import matplotlib as plt
import numpy as np
import requests
import gmaps

from config import api_key
# Census & gmaps API Keys
from config1 import (api_key, gkey)


# Configure gmaps
gmaps.configure(api_key=gkey)

# %%
#import world happyness data
happiness_data2015=pd.read_csv("Resources/happiness/2015.csv")

happiness_data2015_df=happiness_data2015.loc[:,["Country","Happiness Score","Happiness Rank"]]
happiness_data2015_df.head()
# Out:
#        Country  Happiness Score  Happiness Rank
# 0  Switzerland            7.587               1
# 1      Iceland            7.561               2
# 2      Denmark            7.527               3
# 3       Norway            7.522               4
# 4       Canada            7.427               5

# %%
# put city name in a list
countries=happiness_data2015_df["Country"].tolist()

lat=[]
lng=[]
shortname=[]
i=1
for country in countries:
        target_url = ('https://maps.googleapis.com/maps/api/geocode/json?''address={0}&key={1}').format(country, gkey)
        response = requests.get(target_url).json()
        print("Processing Record " + str(i) + " of Set 1 | " + country)
        shortname.append(response['results'][0]['address_components'][0]['short_name'])
        lat.append(response['results'][0]['geometry']['location']["lat"])
        lng.append(response['results'][0]['geometry']['location']["lng"])
        i=i+1
# Out:
# Processing Record 1 of Set 1 | Switzerland
# Processing Record 2 of Set 1 | Iceland
# Processing Record 3 of Set 1 | Denmark
# Processing Record 4 of Set 1 | Norway
# Processing Record 5 of Set 1 | Canada
# Processing Record 6 of Set 1 | Finland
# Processing Record 7 of Set 1 | Netherlands
# Processing Record 8 of Set 1 | Sweden
# Processing Record 9 of Set 1 | New Zealand
# Processing Record 10 of Set 1 | Australia
# Processing Record 11 of Set 1 | Israel
# Processing Record 12 of Set 1 | Costa Rica
# Processing Record 13 of Set 1 | Austria
# Processing Record 14 of Set 1 | Mexico
# Processing Record 15 of Set 1 | United States
# Processing Record 16 of Set 1 | Brazil
# Processing Record 17 of Set 1 | Luxembourg
# Processing Record 18 of Set 1 | Ireland
# Processing Record 19 of Set 1 | Belgium
# Processing Record 20 of Set 1 | United Arab Emirates
# Processing Record 21 of Set 1 | United Kingdom
# Processing Record 22 of Set 1 | Oman
# Processing Record 23 of Set 1 | Venezuela
# Processing Record 24 of Set 1 | Singapore
# Processing Record 25 of Set 1 | Panama
# Processing Record 26 of Set 1 | Germany
# Processing Record 27 of Set 1 | Chile
# Processing Record 28 of Set 1 | Qatar
# Processing Record 29 of Set 1 | France
# Processing Record 30 of Set 1 | Argentina
# Processing Record 31 of Set 1 | Czech Republic
# Processing Record 32 of Set 1 | Uruguay
# Processing Record 33 of Set 1 | Colombia
# Processing Record 34 of Set 1 | Thailand
# Processing Record 35 of Set 1 | Saudi Arabia
# Processing Record 36 of Set 1 | Spain
# Processing Record 37 of Set 1 | Malta
# Processing Record 38 of Set 1 | Taiwan
# Processing Record 39 of Set 1 | Kuwait
# Processing Record 40 of Set 1 | Suriname
# Processing Record 41 of Set 1 | Trinidad and Tobago
# Processing Record 42 of Set 1 | El Salvador
# Processing Record 43 of Set 1 | Guatemala
# Processing Record 44 of Set 1 | Uzbekistan
# Processing Record 45 of Set 1 | Slovakia
# Processing Record 46 of Set 1 | Japan
# Processing Record 47 of Set 1 | South Korea
# Processing Record 48 of Set 1 | Ecuador
# Processing Record 49 of Set 1 | Bahrain
# Processing Record 50 of Set 1 | Italy
# Processing Record 51 of Set 1 | Bolivia
# Processing Record 52 of Set 1 | Moldova
# Processing Record 53 of Set 1 | Paraguay
# Processing Record 54 of Set 1 | Kazakhstan
# Processing Record 55 of Set 1 | Slovenia
# Processing Record 56 of Set 1 | Lithuania
# Processing Record 57 of Set 1 | Nicaragua
# Processing Record 58 of Set 1 | Peru
# Processing Record 59 of Set 1 | Belarus
# Processing Record 60 of Set 1 | Poland
# Processing Record 61 of Set 1 | Malaysia
# Processing Record 62 of Set 1 | Croatia
# Processing Record 63 of Set 1 | Libya
# Processing Record 64 of Set 1 | Russia
# Processing Record 65 of Set 1 | Jamaica
# Processing Record 66 of Set 1 | North Cyprus
# Processing Record 67 of Set 1 | Cyprus
# Processing Record 68 of Set 1 | Algeria
# Processing Record 69 of Set 1 | Kosovo
# Processing Record 70 of Set 1 | Turkmenistan
# Processing Record 71 of Set 1 | Mauritius
# Processing Record 72 of Set 1 | Hong Kong
# Processing Record 73 of Set 1 | Estonia
# Processing Record 74 of Set 1 | Indonesia
# Processing Record 75 of Set 1 | Vietnam
# Processing Record 76 of Set 1 | Turkey
# Processing Record 77 of Set 1 | Kyrgyzstan
# Processing Record 78 of Set 1 | Nigeria
# Processing Record 79 of Set 1 | Bhutan
# Processing Record 80 of Set 1 | Azerbaijan
# Processing Record 81 of Set 1 | Pakistan
# Processing Record 82 of Set 1 | Jordan
# Processing Record 83 of Set 1 | Montenegro
# Processing Record 84 of Set 1 | China
# Processing Record 85 of Set 1 | Zambia
# Processing Record 86 of Set 1 | Romania
# Processing Record 87 of Set 1 | Serbia
# Processing Record 88 of Set 1 | Portugal
# Processing Record 89 of Set 1 | Latvia
# Processing Record 90 of Set 1 | Philippines
# Processing Record 91 of Set 1 | Somaliland region
# Processing Record 92 of Set 1 | Morocco
# Processing Record 93 of Set 1 | Macedonia
# Processing Record 94 of Set 1 | Mozambique
# Processing Record 95 of Set 1 | Albania
# Processing Record 96 of Set 1 | Bosnia and Herzegovina
# Processing Record 97 of Set 1 | Lesotho
# Processing Record 98 of Set 1 | Dominican Republic
# Processing Record 99 of Set 1 | Laos
# Processing Record 100 of Set 1 | Mongolia
# Processing Record 101 of Set 1 | Swaziland
# Processing Record 102 of Set 1 | Greece
# Processing Record 103 of Set 1 | Lebanon
# Processing Record 104 of Set 1 | Hungary
# Processing Record 105 of Set 1 | Honduras
# Processing Record 106 of Set 1 | Tajikistan
# Processing Record 107 of Set 1 | Tunisia
# Processing Record 108 of Set 1 | Palestinian Territories
# Processing Record 109 of Set 1 | Bangladesh
# Processing Record 110 of Set 1 | Iran
# Processing Record 111 of Set 1 | Ukraine
# Processing Record 112 of Set 1 | Iraq
# Processing Record 113 of Set 1 | South Africa
# Processing Record 114 of Set 1 | Ghana
# Processing Record 115 of Set 1 | Zimbabwe
# Processing Record 116 of Set 1 | Liberia
# Processing Record 117 of Set 1 | India
# Processing Record 118 of Set 1 | Sudan
# Processing Record 119 of Set 1 | Haiti
# Processing Record 120 of Set 1 | Congo (Kinshasa)
# Processing Record 121 of Set 1 | Nepal
# Processing Record 122 of Set 1 | Ethiopia
# Processing Record 123 of Set 1 | Sierra Leone
# Processing Record 124 of Set 1 | Mauritania
# Processing Record 125 of Set 1 | Kenya
# Processing Record 126 of Set 1 | Djibouti
# Processing Record 127 of Set 1 | Armenia
# Processing Record 128 of Set 1 | Botswana
# Processing Record 129 of Set 1 | Myanmar
# Processing Record 130 of Set 1 | Georgia
# Processing Record 131 of Set 1 | Malawi
# Processing Record 132 of Set 1 | Sri Lanka
# Processing Record 133 of Set 1 | Cameroon
# Processing Record 134 of Set 1 | Bulgaria
# Processing Record 135 of Set 1 | Egypt
# Processing Record 136 of Set 1 | Yemen
# Processing Record 137 of Set 1 | Angola
# Processing Record 138 of Set 1 | Mali
# Processing Record 139 of Set 1 | Congo (Brazzaville)
# Processing Record 140 of Set 1 | Comoros
# Processing Record 141 of Set 1 | Uganda
# Processing Record 142 of Set 1 | Senegal
# Processing Record 143 of Set 1 | Gabon
# Processing Record 144 of Set 1 | Niger
# Processing Record 145 of Set 1 | Cambodia
# Processing Record 146 of Set 1 | Tanzania
# Processing Record 147 of Set 1 | Madagascar
# Processing Record 148 of Set 1 | Central African Republic
# Processing Record 149 of Set 1 | Chad
# Processing Record 150 of Set 1 | Guinea
# Processing Record 151 of Set 1 | Ivory Coast
# Processing Record 152 of Set 1 | Burkina Faso
# Processing Record 153 of Set 1 | Afghanistan
# Processing Record 154 of Set 1 | Rwanda
# Processing Record 155 of Set 1 | Benin
# Processing Record 156 of Set 1 | Syria
# Processing Record 157 of Set 1 | Burundi
# Processing Record 158 of Set 1 | Togo

# %%
#add lat and lng to the happyness dataframe
happiness_data2015_df["Lat"]=lat
happiness_data2015_df["Lng"]=lng
happiness_data2015_df['Short Name']=shortname

# %%
# select top 20 happiness country and store top20 maker location for lat, lng
top20=happiness_data2015_df.loc[happiness_data2015_df["Happiness Rank"]<21]
top20_marker_locations =top20[["Lat","Lng"]]
top20_countries=top20["Country"]
top20
# Out:
#                  Country  Happiness Score  Happiness Rank        Lat  \
# 0            Switzerland            7.587               1  46.818188
# 1                Iceland            7.561               2  64.963051
# 2                Denmark            7.527               3  56.263920
# 3                 Norway            7.522               4  60.472024
# 4                 Canada            7.427               5  56.130366
# 5                Finland            7.406               6  61.924110
# 6            Netherlands            7.378               7  52.132633
# 7                 Sweden            7.364               8  60.128161
# 8            New Zealand            7.286               9 -40.900557
# 9              Australia            7.284              10 -25.274398
# 10                Israel            7.278              11  31.046051
# 11            Costa Rica            7.226              12   9.748917
# 12               Austria            7.200              13  47.516231
# 13                Mexico            7.187              14  23.634501
# 14         United States            7.119              15  37.090240
# 15                Brazil            6.983              16 -14.235004
# 16            Luxembourg            6.946              17  49.815273
# 17               Ireland            6.940              18  53.142367
# 18               Belgium            6.937              19  50.503887
# 19  United Arab Emirates            6.901              20  23.424076
#
#            Lng Short Name
# 0     8.227512         CH
# 1   -19.020835         IS
# 2     9.501785         DK
# 3     8.468946         NO
# 4  -106.346771         CA
# 5    25.748151         FI
# 6     5.291266         NL
# 7    18.643501         SE
# 8   174.885971         NZ
# 9   133.775136         AU
# 10   34.851612         IL
# 11  -83.753428         CR
# 12   14.550072         AT
# 13 -102.552784         MX
# 14  -95.712891         US
# 15  -51.925280         BR
# 16    6.129583         LU
# 17   -7.692054    Ireland
# 18    4.469936         BE
# 19   53.847818         AE

# %%
# Create a map using top20 Happiness country coordinates to set markers
# Create a marker_layer using the top20 country name list to fill the info box
fig1 = gmaps.figure()
markers1 = gmaps.marker_layer(top20_marker_locations,info_box_content=[f"Country: {country}" for country in top20_countries])
fig1.add_layer(markers1)

fig1
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# select low 20 happiness country and store low 20 maker location for lat, lng
low20=happiness_data2015_df.loc[happiness_data2015_df["Happiness Rank"]>137]
low20_marker_locations =low20[["Lat","Lng"]]
low20_countries=low20["Country"]

# %%
# Create a map using low20 Happiness country coordinates to set markers
# Create a marker_layer using the low20 country name list to fill the info box
fig2 = gmaps.figure()
markers2 = gmaps.marker_layer(low20_marker_locations,info_box_content=[f"Country: {country}" for country in low20_countries])
fig2.add_layer(markers2)
fig2
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#import world current health expenditure data set from csv file and organized the data for analysis
health_current_expenditure = pd.read_csv("Resources/current_expenditure_Data.csv")
health_current_expenditure_2015=health_current_expenditure.loc[:,["Country Name","2015 [YR2015]"]]
health_current_expenditure_2015=health_current_expenditure_2015.rename(columns={"2015 [YR2015]":"2015 Current Health Expediture (%GDP)",
                                                                       "Country Name":"Country"})
#import world domestic govement health expenditure data set from csv file and organized the data for analysis
health_gov_expenditure=pd.read_csv("Resources/Domestic_Govement_Health_Expenditure Data.csv")
health_gov_expenditure_2015=health_gov_expenditure.loc[:,["Country Name","2015 [YR2015]"]]
health_gov_expenditure_2015=health_gov_expenditure_2015.rename(columns={"2015 [YR2015]":"2015 govement Health Expediture (%GDP)",
                                                                       "Country Name":"Country"})

# %%
merge1=happiness_data2015_df.merge(health_current_expenditure_2015,on='Country',how="left")
merge2=merge1.merge(health_gov_expenditure_2015,on='Country',how="left")

merge2.count()
# Out:
# Country                                    158
# Happiness Score                            158
# Happiness Rank                             158
# Lat                                        158
# Lng                                        158
# Short Name                                 158
# 2015 Current Health Expediture (%GDP)_x    138
# 2015 Current Health Expediture (%GDP)_y    138
# dtype: int64

# %%
 print (shortname)
# Out:
# ['CH', 'IS', 'DK', 'NO', 'CA', 'FI', 'NL', 'SE', 'NZ', 'AU', 'IL', 'CR', 'AT', 'MX', 'US', 'BR', 'LU', 'Ireland', 'BE', 'AE', 'GB', 'OM', 'VE', 'SG', 'PA', 'DE', 'CL', 'QA', 'FR', 'AR', 'CZ', 'UY', 'CO', 'TH', 'SA', 'ES', 'MT', 'TW', 'KW', 'SR', 'TT', 'SV', 'GT', 'UZ', 'SK', 'JP', 'KR', 'EC', 'BH', 'IT', 'BO', 'MD', 'PY', 'KZ', 'SI', 'LT', 'NI', 'PE', 'BY', 'PL', 'MY', 'HR', 'LY', 'RU', 'JM', 'Northern Cyprus', 'CY', 'DZ', 'XK', 'TM', 'MU', 'HK', 'EE', 'ID', 'VN', 'TR', 'KG', 'NG', 'BT', 'AZ', 'PK', 'JO', 'ME', 'CN', 'ZM', 'RO', 'RS', 'PT', 'LV', 'PH', 'Somaliland', 'MA', 'MK', 'MZ', 'AL', 'BA', 'LS', 'DO', 'LA', 'MN', 'SZ', 'GR', 'LB', 'HU', 'HN', 'TJ', 'TN', 'PS', 'BD', 'IR', 'UA', 'IQ', 'ZA', 'GH', 'ZW', 'LR', 'IN', 'SD', 'HT', 'CD', 'NP', 'ET', 'SL', 'MR', 'KE', 'DJ', 'AM', 'BW', 'MM', 'GA', 'MW', 'LK', 'CM', 'BG', 'EG', 'YE', 'AO', 'ML', 'Brazzaville', 'KM', 'UG', 'SN', 'GA', 'NE', 'KH', 'TZ', 'MG', 'CF', 'TD', 'GN', 'CI', 'BF', 'AF', 'RW', 'BJ', 'SY', 'BI', 'TG']

# %%
#import world out of pocket expediture
import json 

oop_url="http://apps.who.int/gho/athena/data/GHO/GHED_OOP_pc_US_SHA2011.json?profile=simple&filter=COUNTRY:*;YEAR:2015"
response_OOP = requests.get(oop_url).json()

response_OOP
# Out:
# {'dimension': [{'label': 'GHO', 'display': 'Indicator'},
#   {'label': 'PUBLISHSTATE', 'display': 'PUBLISH STATES'},
#   {'label': 'YEAR', 'display': 'Year'},
#   {'label': 'REGION', 'display': 'WHO region'},
#   {'label': 'COUNTRY', 'display': 'Country'}],
#  'fact': [{'dim': {'PUBLISHSTATE': 'Published',
#     'YEAR': '2015',
#     'REGION': 'Eastern Mediterranean',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Afghanistan'},
#    'Value': '47.1'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Albania',
#     'REGION': 'Europe'},
#    'Value': '151.4'},
#   {'dim': {'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'Africa',
#     'YEAR': '2015',
#     'COUNTRY': 'Algeria',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '81.9'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'REGION': 'Europe',
#     'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Andorra'},
#    'Value': '1570.7'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'REGION': 'Africa',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Angola',
#     'YEAR': '2015'},
#    'Value': '36.2'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Antigua and Barbuda',
#     'YEAR': '2015',
#     'REGION': 'Americas'},
#    'Value': '159.4'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015',
#     'COUNTRY': 'Argentina',
#     'REGION': 'Americas'},
#    'Value': '175.9'},
#   {'dim': {'COUNTRY': 'Armenia',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'Europe',
#     'YEAR': '2015',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '298.8'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'COUNTRY': 'Australia',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'Western Pacific',
#     'YEAR': '2015'},
#    'Value': 'No data'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'Europe',
#     'YEAR': '2015',
#     'COUNTRY': 'Austria'},
#    'Value': '813.0'},
#   {'dim': {'YEAR': '2015',
#     'REGION': 'Europe',
#     'COUNTRY': 'Azerbaijan',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '289.6'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'YEAR': '2015',
#     'REGION': 'Americas',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Bahamas'},
#    'Value': '467.9'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Bahrain',
#     'YEAR': '2015',
#     'REGION': 'Eastern Mediterranean'},
#    'Value': '298.7'},
#   {'dim': {'COUNTRY': 'Bangladesh',
#     'REGION': 'South-East Asia',
#     'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '22.9'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'REGION': 'Americas',
#     'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Barbados'},
#    'Value': '524.0'},
#   {'dim': {'REGION': 'Europe',
#     'COUNTRY': 'Belarus',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '121.5'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'Europe',
#     'COUNTRY': 'Belgium'},
#    'Value': '742.8'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'Americas',
#     'YEAR': '2015',
#     'COUNTRY': 'Belize'},
#    'Value': '68.2'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'YEAR': '2015',
#     'COUNTRY': 'Benin',
#     'REGION': 'Africa',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$'},
#    'Value': '12.7'},
#   {'dim': {'COUNTRY': 'Bhutan',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'South-East Asia',
#     'YEAR': '2015',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '18.0'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'REGION': 'Americas',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015',
#     'COUNTRY': 'Bolivia (Plurinational State of)'},
#    'Value': '51.1'},
#   {'dim': {'YEAR': '2015',
#     'REGION': 'Europe',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Bosnia and Herzegovina',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '123.5'},
#   {'dim': {'REGION': 'Africa',
#     'COUNTRY': 'Botswana',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '20.5'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'COUNTRY': 'Brazil',
#     'REGION': 'Americas',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015'},
#    'Value': '220.8'},
#   {'dim': {'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Brunei Darussalam',
#     'REGION': 'Western Pacific',
#     'YEAR': '2015',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '48.8'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'COUNTRY': 'Bulgaria',
#     'REGION': 'Europe',
#     'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$'},
#    'Value': '272.7'},
#   {'dim': {'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'Africa',
#     'COUNTRY': 'Burkina Faso',
#     'YEAR': '2015',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '12.1'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'YEAR': '2015',
#     'REGION': 'Africa',
#     'COUNTRY': 'Burundi',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$'},
#    'Value': '4.6'},
#   {'dim': {'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'Africa',
#     'COUNTRY': 'Cabo Verde',
#     'YEAR': '2015',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '33.8'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015',
#     'COUNTRY': 'Cambodia',
#     'REGION': 'Western Pacific'},
#    'Value': '41.3'},
#   {'dim': {'COUNTRY': 'Cameroon',
#     'REGION': 'Africa',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '44.4'},
#   {'dim': {'YEAR': '2015',
#     'COUNTRY': 'Canada',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'Americas',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '657.4'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'REGION': 'Africa',
#     'COUNTRY': 'Central African Republic',
#     'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$'},
#    'Value': '6.6'},
#   {'dim': {'COUNTRY': 'Chad',
#     'REGION': 'Africa',
#     'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '20.1'},
#   {'dim': {'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'Americas',
#     'COUNTRY': 'Chile',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '355.3'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'COUNTRY': 'China',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015',
#     'REGION': 'Western Pacific'},
#    'Value': '137.8'},
#   {'dim': {'COUNTRY': 'Colombia',
#     'YEAR': '2015',
#     'REGION': 'Americas',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '68.5'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015',
#     'REGION': 'Africa',
#     'COUNTRY': 'Comoros'},
#    'Value': '43.8'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'YEAR': '2015',
#     'REGION': 'Africa',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Congo'},
#    'Value': '25.8'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Cook Islands',
#     'REGION': 'Western Pacific',
#     'YEAR': '2015'},
#    'Value': '36.9'},
#   {'dim': {'REGION': 'Americas',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Costa Rica',
#     'YEAR': '2015',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '199.6'},
#   {'dim': {'REGION': 'Africa',
#     'YEAR': '2015',
#     'COUNTRY': "Côte d'Ivoire",
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '27.2'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'COUNTRY': 'Croatia',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015',
#     'REGION': 'Europe'},
#    'Value': '129.1'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'Americas',
#     'COUNTRY': 'Cuba'},
#    'Value': '93.8'},
#   {'dim': {'COUNTRY': 'Cyprus',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015',
#     'REGION': 'Europe',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '686.1'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'YEAR': '2015',
#     'COUNTRY': 'Czechia',
#     'REGION': 'Europe',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$'},
#    'Value': '190.4'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': "Democratic People's Republic of Korea",
#     'REGION': 'South-East Asia',
#     'YEAR': '2015'},
#    'Value': 'No data'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'REGION': 'Africa',
#     'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Democratic Republic of the Congo'},
#    'Value': '7.4'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015',
#     'COUNTRY': 'Denmark',
#     'REGION': 'Europe'},
#    'Value': '754.4'},
#   {'dim': {'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'Eastern Mediterranean',
#     'COUNTRY': 'Djibouti',
#     'YEAR': '2015',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '16.7'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'COUNTRY': 'Dominica',
#     'YEAR': '2015',
#     'REGION': 'Americas',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$'},
#    'Value': '109.0'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'Americas',
#     'COUNTRY': 'Dominican Republic'},
#    'Value': '173.3'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'COUNTRY': 'Ecuador',
#     'REGION': 'Americas',
#     'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$'},
#    'Value': '231.7'},
#   {'dim': {'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Egypt',
#     'REGION': 'Eastern Mediterranean',
#     'YEAR': '2015',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '97.1'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'COUNTRY': 'El Salvador',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'Americas',
#     'YEAR': '2015'},
#    'Value': '78.9'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'YEAR': '2015',
#     'COUNTRY': 'Equatorial Guinea',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'Africa'},
#    'Value': '201.6'},
#   {'dim': {'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'Africa',
#     'COUNTRY': 'Eritrea',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '16.2'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'COUNTRY': 'Estonia',
#     'YEAR': '2015',
#     'REGION': 'Europe',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$'},
#    'Value': '253.2'},
#   {'dim': {'COUNTRY': 'Ethiopia',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015',
#     'REGION': 'Africa',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '9.2'},
#   {'dim': {'COUNTRY': 'Fiji',
#     'YEAR': '2015',
#     'REGION': 'Western Pacific',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '37.5'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'COUNTRY': 'Finland',
#     'REGION': 'Europe',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015'},
#    'Value': '796.7'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015',
#     'COUNTRY': 'France',
#     'REGION': 'Europe'},
#    'Value': '273.7'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'Africa',
#     'COUNTRY': 'Gabon',
#     'YEAR': '2015'},
#    'Value': '51.3'},
#   {'dim': {'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'Africa',
#     'YEAR': '2015',
#     'COUNTRY': 'Gambia',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '6.5'},
#   {'dim': {'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Georgia',
#     'REGION': 'Europe',
#     'YEAR': '2015',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '161.0'},
#   {'dim': {'REGION': 'Europe',
#     'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Germany',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '575.3'},
#   {'dim': {'COUNTRY': 'Ghana',
#     'REGION': 'Africa',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '28.7'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'COUNTRY': 'Greece',
#     'REGION': 'Europe',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015'},
#    'Value': '533.6'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'YEAR': '2015',
#     'COUNTRY': 'Grenada',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'Americas'},
#    'Value': '262.5'},
#   {'dim': {'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015',
#     'REGION': 'Americas',
#     'COUNTRY': 'Guatemala',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '125.1'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015',
#     'COUNTRY': 'Guinea',
#     'REGION': 'Africa'},
#    'Value': '13.7'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'YEAR': '2015',
#     'REGION': 'Africa',
#     'COUNTRY': 'Guinea-Bissau',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$'},
#    'Value': '14.7'},
#   {'dim': {'COUNTRY': 'Guyana',
#     'REGION': 'Americas',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '74.7'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'YEAR': '2015',
#     'REGION': 'Americas',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Haiti'},
#    'Value': '19.4'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'COUNTRY': 'Honduras',
#     'REGION': 'Americas',
#     'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$'},
#    'Value': '86.8'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'YEAR': '2015',
#     'COUNTRY': 'Hungary',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'Europe'},
#    'Value': '259.5'},
#   {'dim': {'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Iceland',
#     'YEAR': '2015',
#     'REGION': 'Europe',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '744.5'},
#   {'dim': {'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'South-East Asia',
#     'COUNTRY': 'India',
#     'YEAR': '2015',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '41.2'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'REGION': 'South-East Asia',
#     'YEAR': '2015',
#     'COUNTRY': 'Indonesia',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$'},
#    'Value': '54.0'},
#   {'dim': {'YEAR': '2015',
#     'COUNTRY': 'Iran (Islamic Republic of)',
#     'REGION': 'Eastern Mediterranean',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '145.2'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'COUNTRY': 'Iraq',
#     'REGION': 'Eastern Mediterranean',
#     'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$'},
#    'Value': '118.1'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'COUNTRY': 'Ireland',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'Europe',
#     'YEAR': '2015'},
#    'Value': '721.4'},
#   {'dim': {'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Israel',
#     'YEAR': '2015',
#     'REGION': 'Europe',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '671.6'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015',
#     'COUNTRY': 'Italy',
#     'REGION': 'Europe'},
#    'Value': '616.6'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'REGION': 'Americas',
#     'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Jamaica'},
#    'Value': '69.8'},
#   {'dim': {'COUNTRY': 'Japan',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015',
#     'REGION': 'Western Pacific',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '488.9'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'YEAR': '2015',
#     'REGION': 'Eastern Mediterranean',
#     'COUNTRY': 'Jordan',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$'},
#    'Value': '64.7'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'REGION': 'Europe',
#     'COUNTRY': 'Kazakhstan',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015'},
#    'Value': '147.1'},
#   {'dim': {'YEAR': '2015',
#     'COUNTRY': 'Kenya',
#     'REGION': 'Africa',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '23.4'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'COUNTRY': 'Kiribati',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'Western Pacific',
#     'YEAR': '2015'},
#    'Value': '0.2'},
#   {'dim': {'REGION': 'Eastern Mediterranean',
#     'COUNTRY': 'Kuwait',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '168.1'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'YEAR': '2015',
#     'REGION': 'Europe',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Kyrgyzstan'},
#    'Value': '44.4'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'REGION': 'Western Pacific',
#     'COUNTRY': "Lao People's Democratic Republic",
#     'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$'},
#    'Value': '24.0'},
#   {'dim': {'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'Europe',
#     'COUNTRY': 'Latvia',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '326.3'},
#   {'dim': {'COUNTRY': 'Lebanon',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015',
#     'REGION': 'Eastern Mediterranean',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '206.9'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'REGION': 'Africa',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Lesotho',
#     'YEAR': '2015'},
#    'Value': '15.3'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'REGION': 'Africa',
#     'YEAR': '2015',
#     'COUNTRY': 'Liberia',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$'},
#    'Value': '13.6'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'Eastern Mediterranean',
#     'COUNTRY': 'Libya'},
#    'Value': 'No data'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'REGION': 'Europe',
#     'COUNTRY': 'Lithuania',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015'},
#    'Value': '296.1'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'REGION': 'Europe',
#     'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Luxembourg'},
#    'Value': '663.8'},
#   {'dim': {'YEAR': '2015',
#     'COUNTRY': 'Madagascar',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'Africa',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '4.6'},
#   {'dim': {'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'Africa',
#     'COUNTRY': 'Malawi',
#     'YEAR': '2015',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '3.8'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'COUNTRY': 'Malaysia',
#     'REGION': 'Western Pacific',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015'},
#    'Value': '141.4'},
#   {'dim': {'COUNTRY': 'Maldives',
#     'REGION': 'South-East Asia',
#     'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '154.4'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'REGION': 'Africa',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Mali',
#     'YEAR': '2015'},
#    'Value': '19.6'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'COUNTRY': 'Malta',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015',
#     'REGION': 'Europe'},
#    'Value': '854.9'},
#   {'dim': {'YEAR': '2015',
#     'COUNTRY': 'Marshall Islands',
#     'REGION': 'Western Pacific',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '74.3'},
#   {'dim': {'YEAR': '2015',
#     'COUNTRY': 'Mauritania',
#     'REGION': 'Africa',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '25.9'},
#   {'dim': {'REGION': 'Africa',
#     'YEAR': '2015',
#     'COUNTRY': 'Mauritius',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '256.4'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'COUNTRY': 'Mexico',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015',
#     'REGION': 'Americas'},
#    'Value': '221.3'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'COUNTRY': 'Micronesia (Federated States of)',
#     'REGION': 'Western Pacific',
#     'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$'},
#    'Value': '9.7'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'COUNTRY': 'Monaco',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'Europe',
#     'YEAR': '2015'},
#    'Value': '201.0'},
#   {'dim': {'YEAR': '2015',
#     'COUNTRY': 'Mongolia',
#     'REGION': 'Western Pacific',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '59.9'},
#   {'dim': {'REGION': 'Europe',
#     'COUNTRY': 'Montenegro',
#     'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '121.6'},
#   {'dim': {'YEAR': '2015',
#     'COUNTRY': 'Morocco',
#     'REGION': 'Eastern Mediterranean',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '84.8'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Mozambique',
#     'REGION': 'Africa',
#     'YEAR': '2015'},
#    'Value': '1.9'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'YEAR': '2015',
#     'REGION': 'South-East Asia',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Myanmar'},
#    'Value': '43.7'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'Africa',
#     'COUNTRY': 'Namibia'},
#    'Value': '35.2'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Nauru',
#     'YEAR': '2015',
#     'REGION': 'Western Pacific'},
#    'Value': '10.2'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'South-East Asia',
#     'COUNTRY': 'Nepal'},
#    'Value': '26.8'},
#   {'dim': {'COUNTRY': 'Netherlands',
#     'YEAR': '2015',
#     'REGION': 'Europe',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '581.5'},
#   {'dim': {'COUNTRY': 'New Zealand',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'Western Pacific',
#     'YEAR': '2015',
#     'PUBLISHSTATE': 'Published'},
#    'Value': 'No data'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'REGION': 'Americas',
#     'COUNTRY': 'Nicaragua',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015'},
#    'Value': '58.6'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Niger',
#     'REGION': 'Africa'},
#    'Value': '13.4'},
#   {'dim': {'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015',
#     'REGION': 'Africa',
#     'COUNTRY': 'Nigeria',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '70.3'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015',
#     'COUNTRY': 'Niue',
#     'REGION': 'Western Pacific'},
#    'Value': '16.3'},
#   {'dim': {'REGION': 'Europe',
#     'YEAR': '2015',
#     'COUNTRY': 'Norway',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '1065.3'},
#   {'dim': {'REGION': 'Eastern Mediterranean',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Oman',
#     'YEAR': '2015',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '40.5'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015',
#     'COUNTRY': 'Pakistan',
#     'REGION': 'Eastern Mediterranean'},
#    'Value': '25.3'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'REGION': 'Western Pacific',
#     'COUNTRY': 'Palau',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015'},
#    'Value': '199.9'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'REGION': 'Americas',
#     'COUNTRY': 'Panama',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015'},
#    'Value': '281.0'},
#   {'dim': {'YEAR': '2015',
#     'COUNTRY': 'Papua New Guinea',
#     'REGION': 'Western Pacific',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '4.5'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'REGION': 'Americas',
#     'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Paraguay'},
#    'Value': '117.2'},
#   {'dim': {'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'Americas',
#     'COUNTRY': 'Peru',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '99.8'},
#   {'dim': {'COUNTRY': 'Philippines',
#     'REGION': 'Western Pacific',
#     'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '67.9'},
#   {'dim': {'REGION': 'Europe',
#     'YEAR': '2015',
#     'COUNTRY': 'Poland',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '185.2'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'Europe',
#     'COUNTRY': 'Portugal',
#     'YEAR': '2015'},
#    'Value': '476.1'},
#   {'dim': {'YEAR': '2015',
#     'COUNTRY': 'Qatar',
#     'REGION': 'Eastern Mediterranean',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '126.4'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'REGION': 'Western Pacific',
#     'COUNTRY': 'Republic of Korea',
#     'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$'},
#    'Value': '740.5'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Republic of Moldova',
#     'REGION': 'Europe',
#     'YEAR': '2015'},
#    'Value': '86.1'},
#   {'dim': {'COUNTRY': 'Romania',
#     'REGION': 'Europe',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '94.1'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'REGION': 'Europe',
#     'COUNTRY': 'Russian Federation',
#     'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$'},
#    'Value': '190.8'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'Africa',
#     'YEAR': '2015',
#     'COUNTRY': 'Rwanda'},
#    'Value': '14.7'},
#   {'dim': {'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'Americas',
#     'YEAR': '2015',
#     'COUNTRY': 'Saint Kitts and Nevis',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '513.7'},
#   {'dim': {'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Saint Lucia',
#     'REGION': 'Americas',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '233.0'},
#   {'dim': {'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'Americas',
#     'COUNTRY': 'Saint Vincent and the Grenadines',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '60.9'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'Western Pacific',
#     'COUNTRY': 'Samoa',
#     'YEAR': '2015'},
#    'Value': '25.6'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'COUNTRY': 'San Marino',
#     'REGION': 'Europe',
#     'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$'},
#    'Value': '594.4'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'REGION': 'Africa',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Sao Tome and Principe',
#     'YEAR': '2015'},
#    'Value': '18.7'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Saudi Arabia',
#     'YEAR': '2015',
#     'REGION': 'Eastern Mediterranean'},
#    'Value': '178.9'},
#   {'dim': {'COUNTRY': 'Senegal',
#     'REGION': 'Africa',
#     'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '15.9'},
#   {'dim': {'YEAR': '2015',
#     'COUNTRY': 'Serbia',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'Europe',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '199.4'},
#   {'dim': {'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015',
#     'COUNTRY': 'Seychelles',
#     'REGION': 'Africa',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '12.2'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'YEAR': '2015',
#     'COUNTRY': 'Sierra Leone',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'Africa'},
#    'Value': '40.8'},
#   {'dim': {'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015',
#     'COUNTRY': 'Singapore',
#     'REGION': 'Western Pacific',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '719.4'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'COUNTRY': 'Slovakia',
#     'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'Europe'},
#    'Value': '204.4'},
#   {'dim': {'COUNTRY': 'Slovenia',
#     'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'Europe',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '221.9'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'YEAR': '2015',
#     'REGION': 'Western Pacific',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Solomon Islands'},
#    'Value': '5.0'},
#   {'dim': {'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015',
#     'COUNTRY': 'Somalia',
#     'REGION': 'Eastern Mediterranean',
#     'PUBLISHSTATE': 'Published'},
#    'Value': 'No data'},
#   {'dim': {'COUNTRY': 'South Africa',
#     'REGION': 'Africa',
#     'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '36.2'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'COUNTRY': 'South Sudan',
#     'REGION': 'Africa',
#     'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$'},
#    'Value': '17.2'},
#   {'dim': {'YEAR': '2015',
#     'COUNTRY': 'Spain',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'Europe',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '570.3'},
#   {'dim': {'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Sri Lanka',
#     'REGION': 'South-East Asia',
#     'YEAR': '2015',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '45.3'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'YEAR': '2015',
#     'REGION': 'Eastern Mediterranean',
#     'COUNTRY': 'Sudan',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$'},
#    'Value': '96.0'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Suriname',
#     'YEAR': '2015',
#     'REGION': 'Americas'},
#    'Value': '58.6'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'COUNTRY': 'Eswatini',
#     'REGION': 'Africa',
#     'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$'},
#    'Value': '26.3'},
#   {'dim': {'REGION': 'Europe',
#     'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Sweden',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '850.7'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'COUNTRY': 'Switzerland',
#     'REGION': 'Europe',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015'},
#    'Value': '2783.0'},
#   {'dim': {'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Syrian Arab Republic',
#     'REGION': 'Eastern Mediterranean',
#     'PUBLISHSTATE': 'Published'},
#    'Value': 'No data'},
#   {'dim': {'REGION': 'Europe',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015',
#     'COUNTRY': 'Tajikistan',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '39.7'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Thailand',
#     'REGION': 'South-East Asia'},
#    'Value': '25.5'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Republic of North Macedonia',
#     'REGION': 'Europe',
#     'YEAR': '2015'},
#    'Value': '105.1'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'South-East Asia',
#     'YEAR': '2015',
#     'COUNTRY': 'Timor-Leste'},
#    'Value': '7.3'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Togo',
#     'YEAR': '2015',
#     'REGION': 'Africa'},
#    'Value': '18.7'},
#   {'dim': {'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'Western Pacific',
#     'YEAR': '2015',
#     'COUNTRY': 'Tonga',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '22.6'},
#   {'dim': {'REGION': 'Americas',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015',
#     'COUNTRY': 'Trinidad and Tobago',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '427.9'},
#   {'dim': {'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'Eastern Mediterranean',
#     'YEAR': '2015',
#     'COUNTRY': 'Tunisia',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '102.7'},
#   {'dim': {'YEAR': '2015',
#     'REGION': 'Europe',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Turkey',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '77.0'},
#   {'dim': {'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'REGION': 'Europe',
#     'COUNTRY': 'Turkmenistan',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '287.9'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'COUNTRY': 'Tuvalu',
#     'REGION': 'Western Pacific',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015'},
#    'Value': '3.3'},
#   {'dim': {'COUNTRY': 'Uganda',
#     'REGION': 'Africa',
#     'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '18.7'},
#   {'dim': {'REGION': 'Europe',
#     'YEAR': '2015',
#     'COUNTRY': 'Ukraine',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '59.8'},
#   {'dim': {'COUNTRY': 'United Arab Emirates',
#     'YEAR': '2015',
#     'REGION': 'Eastern Mediterranean',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '249.4'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'United Kingdom of Great Britain and Northern Ireland',
#     'YEAR': '2015',
#     'REGION': 'Europe'},
#    'Value': '644.4'},
#   {'dim': {'COUNTRY': 'United Republic of Tanzania',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015',
#     'REGION': 'Africa',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '8.3'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'COUNTRY': 'United States of America',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'YEAR': '2015',
#     'REGION': 'Americas'},
#    'Value': '1057.0'},
#   {'dim': {'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Uruguay',
#     'REGION': 'Americas',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '207.5'},
#   {'dim': {'YEAR': '2015',
#     'COUNTRY': 'Uzbekistan',
#     'REGION': 'Europe',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '57.2'},
#   {'dim': {'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Vanuatu',
#     'REGION': 'Western Pacific',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '8.8'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'YEAR': '2015',
#     'REGION': 'Americas',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Venezuela (Bolivarian Republic of)'},
#    'Value': '445.8'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'COUNTRY': 'Viet Nam',
#     'REGION': 'Western Pacific',
#     'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$'},
#    'Value': '50.8'},
#   {'dim': {'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Yemen',
#     'YEAR': '2015',
#     'REGION': 'Eastern Mediterranean',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '58.3'},
#   {'dim': {'PUBLISHSTATE': 'Published',
#     'YEAR': '2015',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Zambia',
#     'REGION': 'Africa'},
#    'Value': '19.1'},
#   {'dim': {'YEAR': '2015',
#     'REGION': 'Africa',
#     'GHO': 'Out-of-pocket expenditure (OOP) per capita in US$',
#     'COUNTRY': 'Zimbabwe',
#     'PUBLISHSTATE': 'Published'},
#    'Value': '24.3'}]}

# %%
# Out:
# 'Afghanistan'
